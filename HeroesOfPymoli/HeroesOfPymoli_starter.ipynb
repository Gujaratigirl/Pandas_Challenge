# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data_df = pd.read_csv(file_to_load)
purchase_data_df
#purchase_data_df.columns
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
player_count = len(purchase_data_df["SN"].unique())
player_summary_df = pd.DataFrame({"Total Players": [player_count]})
player_summary_df = player_summary_df.style.set_properties(**{'text-align': 'left'})
player_summary_df
# Out:
# <style  type="text/css" >
# #T_bc372d6a_97f9_11eb_ac21_a683e719d85crow0_col0{
#             text-align:  left;
#         }</style><table id="T_bc372d6a_97f9_11eb_ac21_a683e719d85c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Players</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bc372d6a_97f9_11eb_ac21_a683e719d85clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bc372d6a_97f9_11eb_ac21_a683e719d85crow0_col0" class="data row0 col0" >576</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Calcuate the variables
item_count = len(purchase_data_df["Item Name"].unique())
#price_mean = purchase_data_df["Price"].mean()
price_mean = round(purchase_data_df["Price"].mean(), 2)
total_count = len(purchase_data_df["Purchase ID"])
rev_total = "{:,}".format(purchase_data_df["Price"].sum())



#Create the df
purchase_summary_df = pd.DataFrame({"Number of Unique Items": [item_count],
                                    "Average Price": "$" + str(price_mean),
                                    "Number of Purchases": [total_count],
                                    "Total Revenue": "$" + str(rev_total)}
                                   )
#purchase_summary_df = purchase_summary_df.apply('{:,}'.format)
purchase_summary_df = purchase_summary_df.style.set_properties(**{'text-align': 'left'})
purchase_summary_df
# Out:
# <style  type="text/css" >
# #T_bd3a1128_97f9_11eb_ac21_a683e719d85crow0_col0,#T_bd3a1128_97f9_11eb_ac21_a683e719d85crow0_col1,#T_bd3a1128_97f9_11eb_ac21_a683e719d85crow0_col2,#T_bd3a1128_97f9_11eb_ac21_a683e719d85crow0_col3{
#             text-align:  left;
#         }</style><table id="T_bd3a1128_97f9_11eb_ac21_a683e719d85c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number of Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bd3a1128_97f9_11eb_ac21_a683e719d85clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bd3a1128_97f9_11eb_ac21_a683e719d85crow0_col0" class="data row0 col0" >179</td>
# ...

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
user_summary_df = purchase_data_df.groupby("Gender")
user_summary_df = user_summary_df.sum()
user_summary_df
# Out:
#                        Purchase ID    Age  Item ID    Price
# Gender
# Female                       42870   2412     9659   361.94
# Male                        255921  14942    60698  1967.64
# Other / Non-Disclosed         5019    363     1212    50.19

# %%
#this picks the first occurace of the SN user- passes over the second in the count.
user_summary_df = purchase_data_df.groupby('SN').head(1)
# This counts for 'Gender' column
gender_summary_df = pd.DataFrame(user_summary_df["Gender"].value_counts())
gender_summary_df["Gender"] = gender_summary_df.loc[:,"Gender"].astype(float)
gender_summary_df["Test"] = user_summary_df["Gender"]
gender_summary_df["Test"] = gender_summary_df.loc[:,"Test"].astype(float)
#gender_summary.astype('float64')
gender_summary_df = gender_summary_df.style.set_properties(**{'text-align': 'left'})
gender_summary_df
# Out:
# <style  type="text/css" >
# #T_bde047dc_97f9_11eb_ac21_a683e719d85crow0_col0,#T_bde047dc_97f9_11eb_ac21_a683e719d85crow0_col1,#T_bde047dc_97f9_11eb_ac21_a683e719d85crow1_col0,#T_bde047dc_97f9_11eb_ac21_a683e719d85crow1_col1,#T_bde047dc_97f9_11eb_ac21_a683e719d85crow2_col0,#T_bde047dc_97f9_11eb_ac21_a683e719d85crow2_col1{
#             text-align:  left;
#         }</style><table id="T_bde047dc_97f9_11eb_ac21_a683e719d85c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Gender</th>        <th class="col_heading level0 col1" >Test</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bde047dc_97f9_11eb_ac21_a683e719d85clevel0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_bde047dc_97f9_11eb_ac21_a683e719d85crow0_col0" class="data row0 col0" >484.000000</td>
# ...

# %%
gender_summary_df = user_summary_df.groupby(["Gender"])
print(gender_summary_df)
gender_summary_df.count()
# Out:
# ...
#                        Purchase ID   SN  Age  Item ID  Item Name  Price
# Gender
# Female                          81   81   81       81         81     81
# Male                           484  484  484      484        484    484
# Other / Non-Disclosed           11   11   11       11         11     11

# %%
#player_percent = round(gender_summary/player_count*100,2) Working but not perfect
player_percent = round(gender_summary/gender_summary.sum()*100,2)
#player_percent.astype('int64')
player_percent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-b18766cc7fe1> in <module>
#       1 #player_percent = round(gender_summary/player_count*100,2) Working but not perfect
# ----> 2 player_percent = round(gender_summary/gender_summary.sum()*100,2)
#       3 #player_percent.astype('int64')
#       4 player_percent
#
# NameError: name 'gender_summary' is not defined

# %%
                #player_percent = round(gender_summary["SN"]/player_count*100,2)
                #gender_summary_df.loc[:,['Percentage of Players','SN']]  ## can't get it to just pull selected columns

                ##Pasted to use if needed
                #purchase_summary_df = pd.DataFrame({"Total Count": [gender_summary],
                #                                   "Percentage of Player": "$" + str(#####)}
                #                                   )
        #gender_summary_df = pd.DataFrame({"Total Count":gender_summary,"Percentage of Players": player_percent})
                        #       "Percentage of Players": [player_percent] + "%"})
                #gender_df = gender_summary_df["SN"]
                #gender_df
                #gender_summary_df
#gender_summary_df["Percentage of Players"]= player_percent      
gender_summary_df = pd.DataFrame({"Total Count":gender_summary,
                                  "Percentage of Players": str(player_percent)})
                        #       "Percentage of Players": [player_percent] + "%"})
gender_summary_df = gender_summary_df.style.set_properties(**{'text-align': 'left'})
gender_summary_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-1543a0553712> in <module>
#      12 #gender_summary_df
#      13 #gender_summary_df["Percentage of Players"]= player_percent
# ---> 14 gender_summary_df = pd.DataFrame({"Total Count":gender_summary,
#      15                   "Percentage of Players": str(player_percent)})
#      16         #       "Percentage of Players": [player_percent] + "%"})
#
# NameError: name 'gender_summary' is not defined

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
gender_analysis_count = purchase_data_df["Gender"].value_counts()
        #gender_analysis_count = user_summary_df["Gender"].value_counts()
#gender_analysis_count= purchase_data_df.groupby("Gender").count()
        #gender_analysis_df('SN').count()
gender_analysis_count
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
    grouped_gender_df = purchase_data_df.groupby(['Gender'])
    print(grouped_gender_df)
    grouped_gender_df.count()
    #mean_gender_price = purchase_date_df["Price"].mean()
    #mean_gender_price = gender_summary_df["Price"].mean()
    #mean_gender_price
# Out:
# ...
#                        Purchase ID   SN  Age  Item ID  Item Name  Price
# Gender
# Female                         113  113  113      113        113    113
# Male                           652  652  652      652        652    652
# Other / Non-Disclosed           15   15   15       15         15     15

# %%
grouped_gender_df.head(30)
# Out:
#      Purchase ID             SN  Age                 Gender  Item ID  \
# 0              0        Lisim78   20                   Male      108
# 1              1    Lisovynya38   40                   Male      143
# 2              2     Ithergue48   24                   Male       92
# 3              3  Chamassasya86   24                   Male      100
# 4              4      Iskosia90   23                   Male      131
# ..           ...            ...  ...                    ...      ...
# 484          484    Chanosian48   35  Other / Non-Disclosed       39
# 549          549     Maluncil97   25  Other / Non-Disclosed      146
# 629          629     Maluncil97   25  Other / Non-Disclosed      107
# 637          637         Airi27   24  Other / Non-Disclosed      163
# 747          747   Siarithria38   38  Other / Non-Disclosed      146
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# ...

# %%
test_df =pd.DataFrame(grouped_gender_df["Price"].mean())
test_df
# Out:
#                           Price
# Gender
# Female                 3.203009
# Male                   3.017853
# Other / Non-Disclosed  3.346000

# %%
grouped_gender_df["Price"].sum()
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
grouped_gender_df['Percent'] = (grouped_gender_df['Price']/grouped_gender_df['Price'].sum())*100
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/roperator.py:25: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return right / left
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-bfcfa1986cf6> in <module>
# ----> 1 grouped_gender_df['Percent'] = (grouped_gender_df['Price']/grouped_gender_df['Price'].sum())*100
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ...

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
bins = [0,10,14,19,24,29,34,39,110]
group_names = ["<10","10-14","15-19","20-24","25-29","30-34","35-39","40+"]

user_summary_df["Player Age"] = pd.cut(user_summary_df["Age"],bins, labels=group_names)
user_summary_df
# Out:
# <ipython-input-42-0c5f69e9e6d6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_summary_df["Player Age"] = pd.cut(user_summary_df["Age"],bins, labels=group_names)
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 773          773         Hala31   21    Male       19
# 774          774     Jiskjask80   11    Male       92
# 775          775     Aethedru70   21  Female       60
# ...

# %%
age_group =user_summary_df.groupby("Player Age")
print(age_group["SN"].count())
#age_group("SN").count()
# Out:
# Player Age
# <10       24
# 10-14     15
# 15-19    107
# 20-24    258
# 25-29     77
# 30-34     52
# 35-39     31
# 40+       12
# Name: SN, dtype: int64

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_data_df["Player Age"] = pd.cut(purchase_data_df["Age"],bins, labels=group_names)
purchase_data_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Player Age
# 0    Extraction, Quickblade Of Trembling Hands   3.53      20-24
# 1                            Frenzied Scimitar   1.56        40+
# 2                                 Final Critic   4.88      20-24
# ...

# %%
grouped_age_df = purchase_data_df.groupby(["Player Age"])
print(grouped_age_df)
grouped_age_df.count()
# Out:
# ...
#             Purchase ID   SN  Age  Gender  Item ID  Item Name  Price
# Player Age
# <10                  32   32   32      32       32         32     32
# 10-14                19   19   19      19       19         19     19
# 15-19               136  136  136     136      136        136    136
# 20-24               365  365  365     365      365        365    365
# 25-29               101  101  101     101      101        101    101
# 30-34                73   73   73      73       73         73     73
# 35-39                41   41   41      41       41         41     41
# 40+                  13   13   13      13       13         13     13

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame
